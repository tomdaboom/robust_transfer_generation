# %%
import torch as ch
import matplotlib.pyplot as plt
from robustness.tools.vis_tools import show_image_row, show_image_column

# %%
images = ch.load('./robust_models/trained_images_714623.pt')
print(images.size())
# Out:
# torch.Size([100, 3, 32, 32])

# %%
for i in range(0, len(images), 10):
    imgs = images[i:i+10]
    imgs = ch.clamp(imgs, min=0, max=1)
    show_image_row([imgs.cpu()])
